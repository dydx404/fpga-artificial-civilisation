# %% [markdown]
# # PYNQ Bring-Up
#
# Use this notebook on the board to load the civilisation overlay and check basic control-plane access.

# %%
from pathlib import Path
import sys

sys.path.append(str(Path('..').resolve() / 'python'))
from config import OverlayConfig
from civ_overlay import CivOverlay

config = OverlayConfig(bitstream_path='civ_engine.bit')
engine = CivOverlay(config=config, dry_run=True)
engine.load()
config

# %% [markdown]
# Set `dry_run=False` only after the bitstream exists on the board.
